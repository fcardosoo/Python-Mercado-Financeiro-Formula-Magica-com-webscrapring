# %% [markdown]
# # Projeto 2 - Pegar os dados do site Fundamentus para automatizar o modelo de Factoring Invest

# %% [markdown]
# ## Passo a passo:
#
# * Passo 1: Definir o navegador;
# * Passo 2: Baixar as bibliotecas;
# * Passo 3: Configurar as requisições na internet

# %% [markdown]
# ### Passo 1: Navegador
#
# Google chrome

# %% [markdown]
# ### Passo 2: Bibliotecas

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %% [markdown]
# ### Passo 3:

# %%
#driver = webdriver.Chrome()
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

# %%
url = 'https://www.fundamentus.com.br/resultado.php'
driver.get(url)

# %% [markdown]
# ### Passo 6 - Ler a tabela de Dados

# %%
# Indicando o local dos dados
local_tabela = '/html/body/div[1]/div[2]/table'

# Indicando onde os dados estão no site
elemento = driver.find_element("xpath", local_tabela)

# Pegando a tabela do site
html_tabela = elemento.get_attribute("outerHTML")

tabela = pd.read_html(str(html_tabela), thousands = '.', decimal = ',')[0]

tabela
# Out:
#       Papel  Cotação      P/L   P/VP    PSR Div.Yield  P/Ativo  P/Cap.Giro  \
# 0     IVTT3     0.00     0.00   0.00  0.000     0,00%    0.000        0.00
# 1     MNSA4     0.47     0.00   0.00  0.000     0,00%    0.000        0.00
# 2     PMET3     0.00     0.00   0.00  0.000     0,00%    0.000        0.00
# 3     MNSA3     0.42     0.00   0.00  0.000     0,00%    0.000        0.00
# 4     CSTB4   147.69     0.00   0.00  0.000     0,00%    0.000        0.00
# ..      ...      ...      ...    ...    ...       ...      ...         ...
# 981   PRBC4    14.54   502.29  40.26  0.000     0,00%    0.000        0.00
# 982   UBBR4     7.49   610.27   1.99  0.000     0,00%    0.000        0.00
# 983  UBBR11    14.75  1201.81   3.91  0.000     0,00%    0.000        0.00
# 984   UBBR3    18.00  1466.61   4.77  0.000     0,00%    0.000        0.00
# 985   SQIA3    27.20  2727.51   3.74  3.643     0,20%    1.491       26.88
#
#      P/EBIT  P/Ativ Circ.Liq  ...  EV/EBITDA  Mrg Ebit Mrg. Líq. Liq. Corr.  \
# 0      0.00              0.0  ...       0.00     0,00%     0,00%       0.00
# 1      0.00              0.0  ...       0.00  -208,15%  -362,66%       3.63
# 2      0.00              0.0  ...       0.00     0,00%     0,00%       0.00
# 3      0.00              0.0  ...       0.00  -208,15%  -362,66%       3.63
# 4      0.00              0.0  ...       0.00    40,85%    28,98%       2.60
# ..      ...              ...  ...        ...       ...       ...        ...
# 981    0.00              0.0  ...       0.00     0,00%     0,00%       0.00
# 982    0.00              0.0  ...       0.00     0,00%     0,00%       0.00
# 983    0.00              0.0  ...       0.00     0,00%     0,00%       0.00
# 984    0.00              0.0  ...       0.00     0,00%     0,00%       0.00
# 985   42.97             -3.7  ...      16.39     8,48%     0,45%       1.44
#
#         ROIC      ROE  Liq.2meses   Patrim. Líq  Dív.Brut/ Patrim.  \
# 0      0,00%   -0,40%         0.0  1.083050e+09               0.00
# 1    -13,50%  145,70%         0.0 -9.105000e+06              -6.52
# 2      0,00%    4,10%         0.0 -2.908630e+08               0.00
# 3    -13,50%  145,70%         0.0 -9.105000e+06              -6.52
# 4     22,40%   20,11%         0.0  8.420670e+09               0.14
# ..       ...      ...         ...           ...                ...
# 981    0,00%    8,02%         0.0  1.176410e+09               0.00
# 982    0,00%    0,33%         0.0  1.031720e+10               0.00
# 983    0,00%    0,33%         0.0  1.031720e+10               0.00
# 984    0,00%    0,33%         0.0  1.031720e+10               0.00
# 985    4,04%    0,14%  36634500.0  6.397490e+08               0.67
#
#      Cresc. Rec.5a
# 0           20,67%
# 1          -41,11%
# 2           37,74%
# 3          -41,11%
# 4           31,91%
# ..             ...
# 981         -6,01%
# 982         10,58%
# 983         10,58%
# 984         10,58%
# 985         46,25%
#
# [986 rows x 21 columns]

# %% [markdown]
# ### Passo 7: Construir a tabela final

# %%
tabela = tabela.set_index('Papel')

# %%
tabela = tabela[['Cotação', 'EV/EBIT', 'ROIC', 'Liq.2meses']]
tabela
# Out:
#         Cotação  EV/EBIT     ROIC  Liq.2meses
# Papel
# IVTT3      0.00     0.00    0,00%         0.0
# MNSA4      0.47     0.00  -13,50%         0.0
# PMET3      0.00     0.00    0,00%         0.0
# MNSA3      0.42     0.00  -13,50%         0.0
# CSTB4    147.69     0.00   22,40%         0.0
# ...         ...      ...      ...         ...
# PRBC4     14.54     0.00    0,00%         0.0
# UBBR4      7.49     0.00    0,00%         0.0
# UBBR11    14.75     0.00    0,00%         0.0
# UBBR3     18.00     0.00    0,00%         0.0
# SQIA3     27.20    46.77    4,04%  36634500.0
#
# [986 rows x 4 columns]

# %%
# Tratar a coluna do ROIC
tabela['ROIC'] = tabela['ROIC'].str.replace('%', "")
tabela['ROIC'] = tabela['ROIC'].str.replace('.', "")
tabela['ROIC'] = tabela['ROIC'].str.replace(',', ".")
tabela['ROIC'] = tabela['ROIC'].astype(float)
tabela
# Out:
# C:\Users\d311r.DESKTOP-O2NL7MH\AppData\Local\Temp\ipykernel_10112\91648003.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tabela['ROIC'] = tabela['ROIC'].str.replace('.', "")
#         Cotação  EV/EBIT   ROIC  Liq.2meses
# Papel
# IVTT3      0.00     0.00   0.00         0.0
# MNSA4      0.47     0.00 -13.50         0.0
# PMET3      0.00     0.00   0.00         0.0
# MNSA3      0.42     0.00 -13.50         0.0
# CSTB4    147.69     0.00  22.40         0.0
# ...         ...      ...    ...         ...
# PRBC4     14.54     0.00   0.00         0.0
# UBBR4      7.49     0.00   0.00         0.0
# UBBR11    14.75     0.00   0.00         0.0
# UBBR3     18.00     0.00   0.00         0.0
# SQIA3     27.20    46.77   4.04  36634500.0
#
# [986 rows x 4 columns]

# %% [markdown]
# ### 7.3 Filtros

# %%
tabela = tabela[tabela['Liq.2meses'] > 1000000]
tabela = tabela[tabela['EV/EBIT'] > 0]
tabela = tabela[tabela['ROIC'] > 0]

# %%
tabela['ranking_ev_ebit'] = tabela['EV/EBIT'].rank(ascending = True)
tabela['ranking_roic'] = tabela['ROIC'].rank(ascending = False)
tabela['ranking_total'] = tabela['ranking_ev_ebit'] + tabela['ranking_roic']

# %%
tabela = tabela.sort_values('ranking_total')
tabela
# Out:
#        Cotação  EV/EBIT   ROIC    Liq.2meses  ranking_ev_ebit  ranking_roic  \
# Papel
# PSSA3    25.74     0.21  60.76  3.407740e+07              1.0           1.0
# PETR4    35.70     2.62  28.95  1.740010e+09              4.0           9.5
# PETR3    38.76     2.77  28.95  4.776220e+08              5.0           9.5
# UNIP6    71.54     4.50  38.68  1.601960e+07             14.0           3.0
# WIZC3     5.12     1.92  24.18  4.441510e+06              3.0          16.0
# ...        ...      ...    ...           ...              ...           ...
# CBAV3     3.79    82.23   0.53  1.649930e+07            184.0         186.0
# PCAR3     3.46    42.60   0.24  3.903260e+07            181.0         189.0
# AMAR3     2.18   111.35   0.58  3.197060e+06            187.0         185.0
# BRFS3    10.88   262.92   0.39  2.380210e+08            189.0         187.0
# MRVE3     8.67   171.88   0.33  1.393290e+08            188.0         188.0
#
#        ranking_total
# Papel
# PSSA3            2.0
# PETR4           13.5
# PETR3           14.5
# UNIP6           17.0
# WIZC3           19.0
# ...              ...
# CBAV3          370.0
# PCAR3          370.0
# AMAR3          372.0
# BRFS3          376.0
# MRVE3          376.0
#
# [189 rows x 7 columns]

# %%
tabela.head(10)
# Out:
#        Cotação  EV/EBIT   ROIC    Liq.2meses  ranking_ev_ebit  ranking_roic  \
# Papel
# PSSA3    25.74     0.21  60.76  3.407740e+07              1.0           1.0
# PETR4    35.70     2.62  28.95  1.740010e+09              4.0           9.5
# PETR3    38.76     2.77  28.95  4.776220e+08              5.0           9.5
# UNIP6    71.54     4.50  38.68  1.601960e+07             14.0           3.0
# WIZC3     5.12     1.92  24.18  4.441510e+06              3.0          16.0
# KEPL3    10.67     4.72  43.61  1.339680e+07             19.0           2.0
# VLID3    16.58     4.09  20.64  7.216230e+06              9.5          22.0
# FESA4    48.41     4.68  25.57  8.978620e+06             18.0          14.0
# GOAU4    10.24     1.31  19.35  7.631950e+07              2.0          32.0
# PLPL3     9.57     5.36  30.59  1.308010e+07             29.0           7.0
#
#        ranking_total
# Papel
# PSSA3            2.0
# PETR4           13.5
# PETR3           14.5
# UNIP6           17.0
# WIZC3           19.0
# KEPL3           21.0
# VLID3           31.5
# FESA4           32.0
# GOAU4           34.0
# PLPL3           36.0
